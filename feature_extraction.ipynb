# %%
# File: feature_extraction
# Purpose: Read in .mp4 file, run openCV to binarize, dilate stars, fuse frames together
#          then run blob detection from openCV to extract location, area, and shape. 

import cv2
import numpy as np
import timeit

video_filenames = ["AMOS2019-master/assets/data/simple-bg.mp4",
                   "AMOS2019-master/assets/data/simple-fg.mp4",
                   "AMOS2019-master/assets/data/complex-bg.mp4",
                   "AMOS2019-master/assets/data/complex-fg.mp4"]

# Parameters
#

# Video index
video_num = 1
# Number of frames to fuse together
n_frames = 3
# Thresholding parameter
bin_thresh = 0.1
# Kernel size - adjust so fused images properly show movement and allow blob detection
kernel = np.ones((5,5), 'uint8')


# Set up video reader
vr = cv2.VideoCapture("AMOS2019-master/assets/data/simple-bg.mp4")

# Safety check
if(not vr.isOpened()):
    raise Exception("Error opening video stream or file")

# Loop through video file
while(vr.isOpened()):
    # Start timer
#     start = timeit.timeit()
    
    c_frame = np.zeros((1080,1920))
    # Combine n frames together
    for i in range(n_frames):
        ret, frame = vr.read()
            
        # If succesfully read in frame
        if ret == True:
            # Grayscale
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
            # Binarize
            ret, frame = cv2.threshold(frame, 1,255, cv2.THRESH_BINARY)
            # Dilate
            frame = cv2.dilate(frame, kernel, iterations=1)
        
        if i == 1:
            c_frame = frame.copy()
            continue    
        else:
            c_frame = np.add(c_frame, frame)
    
    
    # Blob detection

    #keypoints = detector.detect(c_frame)
    #print(keypoints)
    contours, hierarchy = cv2.findContours(c_frame, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    #print(contours)
    
    debris_contours = []
    mean_area = 0
    count = 0
    # Find average area
    for c in contours:
        area = cv2.contourArea(c)
        mean_area += area
        count += 1
    mean_area = mean_area / count
    
    
    # Compute bounding box and draw it on the frame
    for c in contours:
        (x,y,w,h) = cv2.boundingRect(c)
        # Area of the contour
        area = cv2.contourArea(c)
        # Perimeter of contour
        perimeter = cv2.contourArea(c)
        # Circularity
        
        # 
        #
        
        
        if area > mean_area:
            cv2.rectangle(c_frame, (x-10,y-10), (x+10+w, y+10+h), (255, 0, 0), 2)
    
#    im_with_keypoints = cv2.drawKeypoints(c_frame, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    
    # End timer
#     end = timeit.timeit()
#     print("Ran code in " + str(end-start) + " seconds")
    
    cv2.imshow('Frame', c_frame)
    cv2.imwrite("media/im_with_keypoints_n_3_gtn_mean_area.png", c_frame)
    
    # Freeze until any key pressed. Quit on pressing q
    if cv2.waitKey(0) & 0xFF == ord('q'):
        break
    
vr.release()
cv2.destroyAllWindows()
    
# Grayscale

# Binarize

# Dilate

# Blob detection

# Store data array as [x, y, height, width, area, shape]. num_blobs by 6 data. store nframes / ntotalframes copies of these.
# train on m frames, predict on ntotalframes-m frames

# Release video capture
#vr.release()

# Close all open frames
#cv2.destroyAllWindows()
# Out:
# Ran code in 0.00047060000019882864 seconds
# Ran code in 2.1000000060666935e-05 seconds
# Ran code in 3.5499999967214535e-05 seconds
# Ran code in 0.00013590000025942572 seconds
# Ran code in 0.0014750999998796033 seconds
# Ran code in 1.9800000018221908e-05 seconds
# Ran code in -9.099999942918657e-06 seconds
# Ran code in -2.3599999849466258e-05 seconds
# Ran code in -1.8199999885837315e-05 seconds
# Ran code in 4.499999931795173e-06 seconds
# Ran code in 9.709999972074002e-05 seconds
# Ran code in 2.0599999970727367e-05 seconds
# Ran code in 0.0002425999998649786 seconds
# Ran code in 0.00017849999994723476 seconds
# Ran code in -0.0003841000000193162 seconds
# Ran code in -1.340000017080456e-05 seconds
# Ran code in 0.00020309999968048942 seconds
# Ran code in 4.4299999899521936e-05 seconds
# Ran code in 0.0001667999999881431 seconds
# Ran code in 2.1299999843904516e-05 seconds
# Ran code in -0.00017219999995177204 seconds
# Ran code in 4.7100000074351556e-05 seconds
# Ran code in -6.470000016634003e-05 seconds
# Ran code in 4.99000000218075e-05 seconds
# Ran code in -2.5899999855028e-05 seconds
# Ran code in -8.529999990969372e-05 seconds
# Ran code in 0.00019560000009732903 seconds
# Ran code in 2.6099999786310946e-05 seconds
# Ran code in -6.200000143508078e-06 seconds
# Ran code in 6.660000008196221e-05 seconds
# Ran code in 2.1800000013172394e-05 seconds
# Ran code in -3.579999997782579e-05 seconds
# Ran code in 2.7600000066740904e-05 seconds
# Ran code in 2.9900000072302646e-05 seconds
# Ran code in 3.7199999951553764e-05 seconds
# Ran code in -1.1999999969702912e-05 seconds
# Ran code in 7.310000000870787e-05 seconds
# Ran code in 7.310000000870787e-05 seconds
# Ran code in -0.000151599999753671 seconds
# Ran code in -1.0599999768601265e-05 seconds
# Ran code in 0.0002615000003061141 seconds
# Ran code in -0.00027730000010706135 seconds
# Ran code in -9.169999998448475e-05 seconds
# Ran code in 1.0999999858540832e-05 seconds
# Ran code in 8.720000005268957e-05 seconds
# Ran code in 2.700000004551839e-05 seconds
# Ran code in 0.00018139999974664534 seconds
# Ran code in 0.00011450000010881922 seconds
# Ran code in 2.0100000028833165e-05 seconds
# Ran code in -0.00023279999982150912 seconds
# Ran code in -3.770000012082164e-05 seconds
# Ran code in -0.0002589000000625674 seconds
# Ran code in 8.50000014906982e-06 seconds
# Ran code in 8.04999999672873e-05 seconds
# Ran code in 3.500000002532033e-05 seconds
# Ran code in 0.00013219999982538866 seconds
# Ran code in 6.759999996575061e-05 seconds
# Ran code in 4.850000004807953e-05 seconds
# Ran code in 0.00012710000009974465 seconds
# Ran code in 0.00010919999999714491 seconds
# Ran code in 0.0002051999999821419 seconds
# Ran code in 0.00020759999983965827 seconds
# Ran code in 0.00010229999998045969 seconds
# Ran code in 0.00037500000007639755 seconds
# Ran code in 7.609999988744676e-05 seconds
# Ran code in 0.0001617000000351254 seconds
# Ran code in 3.459999970800709e-05 seconds
# Ran code in -2.40000001667795e-05 seconds
# Ran code in -5.3800000159753836e-05 seconds
# Ran code in -0.00017800000000534055 seconds
# Ran code in 0.00023229999965224124 seconds
# Ran code in -2.7199999976801337e-05 seconds
# Ran code in 0.00012390000006234914 seconds
# Ran code in 2.1100000139995245e-05 seconds
# Ran code in 0.00017860000002656307 seconds
# Ran code in 2.5000000050567905e-05 seconds
# Ran code in -0.0003263999999489897 seconds
# Ran code in -0.00025119999986600305 seconds
# Ran code in 0.0004598999998961517 seconds
# Ran code in 8.559999992030498e-05 seconds
# Ran code in 0.0003222000000278058 seconds
# Ran code in 0.0006713000000218017 seconds
# Ran code in 5.410000017036509e-05 seconds
# Ran code in 0.0006330000001071312 seconds
# Ran code in 0.0002660000000105356 seconds
# Ran code in 0.00015030000008664501 seconds
# Ran code in 0.0002779999999802385 seconds
# Ran code in 0.00031930000000102154 seconds
# Ran code in 0.000125699999898643 seconds
# Ran code in 0.0003850999999031046 seconds
# Ran code in 0.000404400000206806 seconds
# Ran code in -5.7800000149654807e-05 seconds
# Ran code in 0.00017270000012103992 seconds
# Ran code in 0.0007519999999203719 seconds
# Ran code in 0.00011859999972330115 seconds
# Ran code in 0.0002752999998847372 seconds
# Ran code in 0.0006438999998863437 seconds
# Ran code in 0.0005839000000378292 seconds
# Ran code in 0.0016031999998631363 seconds
# Ran code in 0.00023450000003322202 seconds
# Ran code in 0.0002040999997916515 seconds
# Ran code in 0.0002194000001054519 seconds
# Ran code in 0.0006781999998111132 seconds
# Ran code in 0.00016589999995630933 seconds
# Ran code in 0.0006654999999682332 seconds
# Ran code in 0.00028459999998631247 seconds
# Ran code in 0.00028670000006059126 seconds
# Ran code in 0.0008794000000307278 seconds
# Ran code in 0.0009170000000722212 seconds
# Ran code in 6.299999995462713e-05 seconds
# Ran code in 0.0002399999998488056 seconds
# Ran code in 0.0005075999997643521 seconds
# Ran code in 0.0001029000000016822 seconds
# Ran code in 0.00023950000013428507 seconds
# Ran code in 0.00035099999990961805 seconds
# Ran code in 0.0017789999999422434 seconds
# Ran code in 0.000403099999857659 seconds
# Ran code in 0.00023889999988568889 seconds
# Ran code in 9.799999997994746e-05 seconds
# Ran code in 0.000220299999909912 seconds
# Ran code in 0.0004039000000375381 seconds
# Ran code in 3.620000006776536e-05 seconds
# Ran code in 0.00032279999982165464 seconds
# Ran code in 0.00025379999988217605 seconds
# Ran code in 0.00026419999994686805 seconds
# Ran code in -3.530000003593159e-05 seconds
# Ran code in 7.349999987127376e-05 seconds
# Ran code in 0.00015430000007654598 seconds
# Ran code in 9.989999989556964e-05 seconds
# Ran code in 0.0003240999997160543 seconds
# Ran code in 0.00016560000017307175 seconds
# Ran code in 0.00033970000026783964 seconds
# Ran code in 0.0007510000000365835 seconds
# Ran code in -1.6399999822169775e-05 seconds
# Ran code in 0.0007583000001432083 seconds
# Ran code in 0.00021440000023176253 seconds
# Ran code in 6.470000016634003e-05 seconds
# Ran code in -2.5900000082401675e-05 seconds
# Ran code in 0.00015330000019275758 seconds
# Ran code in 1.6899999764063978e-05 seconds
# Ran code in -4.859999990003416e-05 seconds
# Ran code in 0.0003985000000739092 seconds
# Ran code in 4.699999863078119e-06 seconds
# Ran code in 3.709999987222545e-05 seconds
# Ran code in 9.919999979501881e-05 seconds
# Ran code in 8.700000080352766e-06 seconds
# Ran code in 1.6100000038932194e-05 seconds
# Ran code in 2.040000003944442e-05 seconds
# Ran code in -3.46999997873354e-05 seconds
# Ran code in 8.900000011635711e-06 seconds
# Ran code in 0.00019779999979618879 seconds
# Ran code in 2.480000011928496e-05 seconds
# Ran code in 7.439999990310753e-05 seconds
# Ran code in 6.200000143508078e-06 seconds
# Ran code in 0.00043740000000980217 seconds
# Ran code in -0.00012000000015177648 seconds
# Ran code in 3.5299999808557914e-05 seconds
# Ran code in 0.000273500000275817 seconds
# Ran code in 0.0002805999999964115 seconds
# Ran code in 4.639999997380073e-05 seconds
# Ran code in -0.00010629999997036066 seconds
# Ran code in -4.959999978382257e-05 seconds
# Ran code in 9.900000122797792e-06 seconds
# Ran code in 0.0004427999999734311 seconds
# Ran code in 0.0002581999999620166 seconds
# Ran code in 7.800000048518996e-06 seconds
# Ran code in -0.00016750000008869392 seconds
# Ran code in -0.00036410000006981136 seconds
# Ran code in 0.00047220000010383956 seconds
# Ran code in 4.539999986263865e-05 seconds
# Ran code in 0.00030540000011569646 seconds
# Ran code in 3.0499999866151484e-05 seconds
# Ran code in -0.00014780000014980033 seconds
# Ran code in 0.0005741000002217334 seconds
# Ran code in 0.0356398999999783 seconds

# %%
print(dir(keypoints[0]))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'angle', 'class_id', 'convert', 'octave', 'overlap', 'pt', 'response', 'size']
